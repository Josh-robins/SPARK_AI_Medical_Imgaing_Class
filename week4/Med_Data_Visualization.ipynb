# %% [markdown]
# <a href="https://colab.research.google.com/github/Josh-robins/SPARK_AI_Medical_Imgaing_Class/blob/main/week4/Med_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Data Visualization 🤗

# %% [markdown]
# The aim of this Notebook is to introduce you to data visualization with Python.
#
# Some of the major Pros 👍 of Matplotlib are:
#
# *   Generally easy to get started for simple plots
# *   Support for custom labels and texts
# *   Great control of every element in a figure
# *   High-quality output in many formats
# *   Very customizable in general

# %% [markdown]
# #Exploring Datasets with *pandas* 🐼
#
# *pandas* is an essential data analysis toolkit for Python. [website](http://pandas.pydata.org/):
# >*pandas* is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental for **real world** data analysis in Python.

# %% [markdown]
# ![téléchargé (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Healthcare Dataset 🏥

# %% [markdown]
# First Import two key data analysis modules: *pandas* and **Numpy**.

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %% [markdown]
# Let's download and import our healthcare dataste.

# %%
import pandas as pd
# Download Data from here : "https://www.kaggle.com/datasets/khawlaalaoui/healthcare-dataset"
df = pd.read_csv("healthcare_dataset.csv")
# Now, 'df' holds the data in a DataFrame

# %% [markdown]
# Now we are ready to read in our data.

# %% [markdown]
# Let's view the top 5 rows of the dataset using the `head()` function.

# %%
# Let's display
df.head(5)
# tip: You can specify the number of rows you'd like to see.
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        11/17/2022  Patrick Parker           Wallace-Hamilton
# 1          6/1/2023   Diane Jackson  Burke, Griffin and Cooper
# 2          1/9/2019      Paul Baker                 Walton LLC
# 3          5/2/2020  Brian Chandler                 Garcia Ltd
# 4          7/9/2021  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare           37491          146       Elective
# 1   UnitedHealthcare           47304          404      Emergency
# 2           Medicare           36875          292      Emergency
# 3           Medicare           23303          480         Urgent
# 4   UnitedHealthcare           18086          477         Urgent
#
#   Discharge Date   Medication  Test Results
# 0      12/1/2022      Aspirin  Inconclusive
# 1      6/15/2023      Lipitor        Normal
# 2       2/8/2019      Lipitor        Normal
# 3       5/3/2020   Penicillin      Abnormal
# 4       8/2/2021  Paracetamol        Normal

# %%
# Task : display 10 raws from the dataset
# ....

# %% [markdown]
# We can also view the bottom 5 rows of the dataset using the `tail()` function.

# %%
df.tail()
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# 9995         7/29/2022       Samuel Moody   Wood, Martin and Simmons
# 9996          1/6/2022  Christopher Yates               Nash-Krueger
# 9997          7/1/2022   Robert Nicholson            Larson and Sons
# 9998          2/6/2020        Jamie Lewis               Wilson-Lyons
# 9999         3/22/2023        Tasha Avila  Torres, Young and Stewart
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# 9995   UnitedHealthcare           39607          110       Elective
# 9996         Blue Cross            5996          244      Emergency
# 9997         Blue Cross           49559          312       Elective
# 9998   UnitedHealthcare           25236          420         Urgent
# 9999              Aetna           37224          290      Emergency
#
#      Discharge Date  Medication Test Results
# 9995       8/2/2022   Ibuprofen     Abnormal
# 9996      1/29/2022   Ibuprofen       Normal
# 9997      7/15/2022   Ibuprofen       Normal
# 9998      2/26/2020  Penicillin       Normal
# 9999      4/15/2023  Penicillin     Abnormal

# %% [markdown]
# When analyzing a dataset, it's always a good idea to start by getting basic information about your dataframe. We can do this by using the `info()` method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  int64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ######Note: The main types stored in *pandas* objects are *float*, *int*, *bool*, *datetime64[ns]* and *datetime64[ns, tz] (in >= 0.17.0)*, *timedelta[ns]*, *category (in >= 0.15.0)*, and *object* (string). In addition these dtypes have item sizes, e.g. int64 and int32.

# %% [markdown]
# To get the list of column headers we can call upon the dataframe's `.columns` parameter.

# %%
df.columns.values
# Out:
# array(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type',
#        'Discharge Date', 'Medication', 'Test Results'], dtype=object)

# %% [markdown]
# Similarly, to get the list of indicies we use the `.index` parameter.

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999])

# %% [markdown]
# Note: The default type of index and columns is NOT list.

# %%
print(type(df.columns))
print(type(df.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.range.RangeIndex'>

# %% [markdown]
# To get the index and columns as lists for easier use, we can use the `tolist()` method.

# %%
df.columns.tolist()
df.index.tolist()
# Check if they did change
print (type(df.columns.tolist()))
print (type(df.index.tolist()))
# Out:
# <class 'list'>
# <class 'list'>

# %% [markdown]
# To view the dimensions of the dataframe, we use the `.shape` parameter.

# %%
# size of dataframe (rows, columns)
df.shape
# Out:
# (10000, 15)

# %%
# Droping rows with missing values
df.dropna(inplace=True)

# %%
# Removing duplicate rows
df.drop_duplicates(inplace=True)

# %% [markdown]
# For data cleaning, we may remove unnecessary columns. So we can use *pandas* `drop()` method:

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
df.drop(['Room Number'], axis=1, inplace=True)
df.head(2)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 6252        William Martin   26    Male        AB+         Arthritis
# 4684  Christopher Campbell   80  Female         A+           Obesity
#
#      Date of Admission        Doctor                   Hospital  \
# 6252         7/27/2020  David Cherry  Obrien, Rogers and Garcia
# 4684         2/23/2022  Kevin Martin                 Pace Group
#
#      Insurance Provider  Billing Amount Admission Type Discharge Date  \
# 6252              Aetna           48229       Elective       8/9/2020
# 4684   UnitedHealthcare            5634      Emergency      3/18/2022
#
#        Medication  Test Results
# 6252    Ibuprofen  Inconclusive
# 4684  Paracetamol        Normal

# %% [markdown]
# We can also rename the columns. Using `rename()` method by passing in a dictionary of old and new names as follows:

# %%
df.rename(columns={'Medical Condition':'Disease', 'Date of Admission':'Entry Date'}, inplace=True)
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Disease', 'Entry Date',
#        'Doctor', 'Hospital', 'Insurance Provider', 'Billing Amount',
#        'Admission Type', 'Discharge Date', 'Medication', 'Test Results'],
#       dtype='object')

# %%
# Converting 'Entry Date' and 'Discharge date' columns to datetime format
df['Entry Date'] = pd.to_datetime(df['Entry Date'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %% [markdown]
# So let's view some statistical values through a quick summary of "Int" columns in our dataframe using the `describe()` method.

# %%
df.describe()
# Out:
#               Age                     Entry Date  Billing Amount  \
# count  500.000000                            500      500.000000
# mean    52.370000  2021-05-30 06:28:47.999999744    25602.662000
# min     18.000000            2018-11-01 00:00:00     1332.000000
# 25%     35.750000            2020-04-23 00:00:00    13011.000000
# 50%     53.000000            2021-06-10 12:00:00    25239.500000
# 75%     69.000000            2022-09-07 00:00:00    37746.750000
# max     85.000000            2023-10-30 00:00:00    49974.000000
# std     19.509134                            NaN    14160.301784
#
#                       Discharge Date
# count                            500
# mean   2021-06-15 05:13:55.200000256
# min              2018-11-09 00:00:00
# 25%              2020-05-09 00:00:00
# 50%              2021-06-23 12:00:00
# 75%              2022-09-18 18:00:00
# max              2023-11-18 00:00:00
# std                              NaN

# %% [markdown]
# The summary include things like:
#
# * count: The number of non-missing values in the column.
# * mean: The average of the values in the column.
# * std: The standard deviation, showing how spread out the data is.
# * min: The smallest value in the column.
# * 25%: The 25th percentile (the value below which 25% of the data falls).
# * 50%: The 50th percentile (also known as the median).
# * 75%: The 75th percentile.
# * max: The largest value in the column.

# %% [markdown]
# ---
# ## *pandas* Intermediate: Indexing and Selection (slicing)

# %% [markdown]
# ### Select Column
# **There are two ways to filter on a column name:**
#
# Method 1: Quick and easy, but only works if the column name does NOT have spaces or special characters.
# ```python
#     df.column_name
#         (returns series)
# ```
#
# Method 2: More robust, and can filter on multiple columns.
#
# ```python
#     df['column']
#         (returns series)
# ```
#
# ```python
#     df[['column 1', 'column 2']]
#         (returns dataframe)
# ```
# ---

# %% [markdown]
# Example: Let's try filtering on the list of doctors we have ('Doctor').

# %%
df.Doctor  # returns a series
# Out:
# 6252        David Cherry
# 4684        Kevin Martin
# 1731         Kelly Watts
# 4742    Steven Carpenter
# 4521          Joseph Ray
#               ...
# 5170           Cindy Ray
# 7205        Sandra Green
# 2522     Danny Mccormick
# 2215       Luis Gonzalez
# 6968    Alison Patterson
# Name: Doctor, Length: 500, dtype: object

# %% [markdown]
# Let's try filtering on the list of Patients and the Billing Amount.

# %%
df[['Name', 'Billing Amount']] # returns a dataframe
# Out:
#                       Name  Billing Amount
# 6252        William Martin           48229
# 4684  Christopher Campbell            5634
# 1731         Kristy Thomas           25850
# 4742         Melissa Pitts           37016
# 4521           Donna Evans           25426
# ...                    ...             ...
# 5170          Adam Mueller           36704
# 7205          Renee Taylor           42271
# 2522            Lisa Lucas           19535
# 2215      Michael Anderson           35706
# 6968            Sue Peters           36922
#
# [500 rows x 2 columns]

# %% [markdown]
# ### Select Row
#
# There are main 2 ways to select rows:
#
# ```python
#     df.loc[label]
#         #filters by the labels of the index/column
#     df.iloc[index]
#         #filters by the positions of the index/column
# ```

# %% [markdown]
# Before we proceed, notice that the defaul index of the dataset is a numeric range from 0 to 9999. This makes it very difficult to do a query by a specific patient. For example to search for data on 'Jesse Williams', we need to know the corressponding index value.
#
# This can be fixed very easily by setting the 'Name' column as the index using `set_index()` method.

# %%
df.set_index('Name', inplace=True)
# tip: The opposite of set is reset. So to reset the index, we can use df.reset_index()

# %%
df.head(3)
# Out:
#                       Age  Gender Blood Type    Disease Entry Date  \
# Name
# William Martin         26    Male        AB+  Arthritis 2020-07-27
# Christopher Campbell   80  Female         A+    Obesity 2022-02-23
# Kristy Thomas          68  Female        AB+   Diabetes 2020-02-02
#
#                             Doctor                   Hospital  \
# Name
# William Martin        David Cherry  Obrien, Rogers and Garcia
# Christopher Campbell  Kevin Martin                 Pace Group
# Kristy Thomas          Kelly Watts                Berry Group
#
#                      Insurance Provider  Billing Amount Admission Type  \
# Name
# William Martin                    Aetna           48229       Elective
# Christopher Campbell   UnitedHealthcare            5634      Emergency
# Kristy Thomas                     Cigna           25850         Urgent
#
#                      Discharge Date   Medication  Test Results
# Name
# William Martin           2020-08-09    Ibuprofen  Inconclusive
# Christopher Campbell     2022-03-18  Paracetamol        Normal
# Kristy Thomas            2020-02-17    Ibuprofen  Inconclusive

# %%
# optional: to remove the name of the index
df.index.name = None

# %%
# 1. the full row data (all columns)
print(df.loc['Jesse Williams'])

# %%
# alternate method
print(df.iloc[87])
# Out:
# Age                                    44
# Gender                               Male
# Blood Type                            AB+
# Disease                         Arthritis
# Entry Date            2023-08-20 00:00:00
# Doctor                   Patrick Ferguson
# Hospital                  Franklin-Phelps
# Insurance Provider                  Aetna
# Billing Amount                      34550
# Admission Type                     Urgent
# Discharge Date        2023-08-29 00:00:00
# Medication                        Lipitor
# Test Results                 Inconclusive
# Name: Nicholas Garrett, dtype: object

# %% [markdown]
# ### Filtering based on a criteria
# To filter the dataframe based on a condition, we simply pass the condition as a boolean vector.
#
# For example, Let's filter the dataframe to show the gender (Gender = Male).

# %%
# 1. create the condition boolean series
condition = df['Gender'] == 'Male'
print(condition)
# Out:
# William Martin           True
# Christopher Campbell    False
# Kristy Thomas           False
# Melissa Pitts            True
# Donna Evans              True
#                         ...
# Adam Mueller             True
# Renee Taylor             True
# Lisa Lucas              False
# Michael Anderson        False
# Sue Peters              False
# Name: Gender, Length: 500, dtype: bool

# %%
# 2. pass this condition into the dataFrame
df[condition]
# Out:
#                    Age Gender Blood Type       Disease Entry Date  \
# William Martin      26   Male        AB+     Arthritis 2020-07-27
# Melissa Pitts       61   Male         O+        Asthma 2020-09-04
# Donna Evans         78   Male         B-       Obesity 2020-09-17
# Mr. Gary Lynn       80   Male         A-     Arthritis 2019-05-19
# Jennifer Williams   59   Male         O+  Hypertension 2020-07-17
# ...                ...    ...        ...           ...        ...
# Dustin Myers        19   Male         O+      Diabetes 2022-09-29
# Michelle Peterson   42   Male         O+     Arthritis 2023-01-04
# Johnny Howard       31   Male        AB-       Obesity 2019-07-28
# Adam Mueller        26   Male         B-  Hypertension 2023-02-20
# Renee Taylor        77   Male         A+      Diabetes 2020-06-04
#
#                              Doctor                       Hospital  \
# William Martin         David Cherry      Obrien, Rogers and Garcia
# Melissa Pitts      Steven Carpenter                   Ortega Group
# Donna Evans              Joseph Ray        Smith, Nelson and Greer
# Mr. Gary Lynn          David Fields     Bailey, Perry and Hamilton
# Jennifer Williams        Eric Clark             Rasmussen-Williams
# ...                             ...                            ...
# Dustin Myers         Joshua Jenkins                   Robinson PLC
# Michelle Peterson        Mary Grant                Berger and Sons
# Johnny Howard           Paul Howell                Walters-Salazar
# Adam Mueller              Cindy Ray                 Adams and Sons
# Renee Taylor           Sandra Green  Ramirez, Campbell and Schmidt
#
#                   Insurance Provider  Billing Amount Admission Type  \
# William Martin                 Aetna           48229       Elective
# Melissa Pitts                  Aetna           37016         Urgent
# Donna Evans                    Cigna           25426      Emergency
# Mr. Gary Lynn                  Cigna           44565         Urgent
# Jennifer Williams         Blue Cross           39301         Urgent
# ...                              ...             ...            ...
# Dustin Myers                   Cigna            1828      Emergency
# Michelle Peterson              Aetna           11281       Elective
# Johnny Howard                  Cigna            6109       Elective
# Adam Mueller                Medicare           36704         Urgent
# Renee Taylor                   Aetna           42271       Elective
#
#                   Discharge Date   Medication  Test Results
# William Martin        2020-08-09    Ibuprofen  Inconclusive
# Melissa Pitts         2020-09-30      Aspirin  Inconclusive
# Donna Evans           2020-10-05  Paracetamol      Abnormal
# Mr. Gary Lynn         2019-06-16      Lipitor      Abnormal
# Jennifer Williams     2020-07-22   Penicillin        Normal
# ...                          ...          ...           ...
# Dustin Myers          2022-10-17    Ibuprofen        Normal
# Michelle Peterson     2023-01-31   Penicillin        Normal
# Johnny Howard         2019-08-03      Aspirin        Normal
# Adam Mueller          2023-03-21  Paracetamol      Abnormal
# Renee Taylor          2020-06-10      Lipitor  Inconclusive
#
# [240 rows x 13 columns]

# %%
# we can pass mutliple criteria in the same line.
# let's filter for Gender = Male and Disease = Diabetes

df[(df['Gender']=='Male') & (df['Disease']=='Diabetes')]

# note: When using 'and' and 'or' operators, pandas requires we use '&' and '|' instead of 'and' and 'or'
# don't forget to enclose the two conditions in parentheses
# Out:
#                      Age Gender Blood Type   Disease Entry Date  \
# Elizabeth Wong        55   Male         O+  Diabetes 2021-07-12
# Mark Barnes           74   Male         O-  Diabetes 2021-11-19
# Benjamin Stone        50   Male        AB-  Diabetes 2018-11-17
# Jacob Atkins          80   Male         O+  Diabetes 2020-10-26
# Mercedes Mitchell     76   Male        AB-  Diabetes 2018-12-15
# Jonathan Brady        66   Male         A-  Diabetes 2023-06-26
# Lisa Ramirez          81   Male         O+  Diabetes 2019-12-20
# Mark Maxwell          74   Male         B-  Diabetes 2022-05-30
# Abigail Horn          82   Male        AB+  Diabetes 2021-10-26
# Kayla Herrera         74   Male        AB-  Diabetes 2022-07-03
# Elizabeth Martinez    71   Male        AB+  Diabetes 2022-01-27
# Samuel Johnson        32   Male         O-  Diabetes 2023-01-29
# Robert Payne          46   Male        AB+  Diabetes 2021-01-01
# Sandra Green          82   Male         B+  Diabetes 2021-10-09
# Daniel Wilkinson      40   Male         O-  Diabetes 2021-10-12
# Richard Morrow        34   Male         A-  Diabetes 2019-08-11
# Jonathan Cunningham   60   Male         O-  Diabetes 2020-11-09
# John Marshall         61   Male         B+  Diabetes 2021-11-18
# Nancy Lopez           42   Male         O+  Diabetes 2023-08-20
# Joyce Vaughn          33   Male         O-  Diabetes 2021-09-22
# Carrie Lowe           73   Male         A-  Diabetes 2022-05-30
# Trevor Compton        45   Male        AB+  Diabetes 2019-11-07
# Kimberly Cruz         33   Male         B-  Diabetes 2023-01-19
# Adam Bryant           31   Male         A-  Diabetes 2021-04-02
# Lori Phillips         34   Male         A+  Diabetes 2022-01-24
# Aaron Wilson          80   Male         A-  Diabetes 2020-07-27
# James Johnson         28   Male         B-  Diabetes 2022-10-08
# Dan Nash              85   Male         B+  Diabetes 2021-09-06
# Jennifer Sutton       74   Male         A-  Diabetes 2022-05-31
# Jennifer Gibson       83   Male         A+  Diabetes 2019-01-17
# Patrick Smith         31   Male         O+  Diabetes 2019-11-01
# Kenneth Yu            55   Male        AB-  Diabetes 2023-08-24
# Melinda Dunn          35   Male         A+  Diabetes 2021-03-03
# Courtney Wilson       28   Male        AB+  Diabetes 2022-02-21
# Theresa Anderson      84   Male        AB+  Diabetes 2022-01-17
# Nathan Campbell       20   Male         B-  Diabetes 2018-12-14
# Hannah Garcia         36   Male         O-  Diabetes 2022-12-29
# Angela Griffith MD    48   Male         B+  Diabetes 2020-12-22
# Aimee Farmer          38   Male        AB+  Diabetes 2019-07-30
# Jill Brandt           60   Male         O-  Diabetes 2020-07-19
# John Perez            43   Male         A+  Diabetes 2020-11-20
# Crystal Gardner       24   Male         O+  Diabetes 2021-02-06
# Dustin Myers          19   Male         O+  Diabetes 2022-09-29
# Renee Taylor          77   Male         A+  Diabetes 2020-06-04
#
#                                   Doctor                       Hospital  \
# Elizabeth Wong           Alexander Bates                   Brown-Torres
# Mark Barnes                 Roberto Wood     Trevino, Butler and Phelps
# Benjamin Stone                Jon Prince  Johnson, Rodriguez and Martin
# Jacob Atkins              Douglas Benton        Fox, Ramirez and Thomas
# Mercedes Mitchell           Andrea Wells                  Frey and Sons
# Jonathan Brady             Matthew White   Foster, Williams and Johnson
# Lisa Ramirez              Kenneth Carter                Barnes-Harrison
# Mark Maxwell                   Ashley Le    Santiago, Rogers and Juarez
# Abigail Horn           Elizabeth Flowers         Bean, Knox and Bullock
# Kayla Herrera              Angela Branch                   Anderson LLC
# Elizabeth Martinez           Cory Phelps                   Carter-Davis
# Samuel Johnson             Carrie Carter    Rose, Richard and Hernandez
# Robert Payne                Mark Parrish                      Moses PLC
# Sandra Green                Diana Castro                     Evans-Todd
# Daniel Wilkinson              Eric Bowen               Esparza and Sons
# Richard Morrow             Steven Rivera      Jordan, Hudson and Hughes
# Jonathan Cunningham         Pamela Reyes      Cisneros, Willis and Owen
# John Marshall                James Perez                    Davis-Jones
# Nancy Lopez                  Frank Pratt        Hill, Cannon and Butler
# Joyce Vaughn              Angelica Gross      Mcintyre, Stein and Jones
# Carrie Lowe               Richard George                  Nguyen-Wilson
# Trevor Compton            Tamara Stevens    Kennedy, Garrett and Fowler
# Kimberly Cruz               Isaac Walker                  Bass and Sons
# Adam Bryant          Miss Kayla Ruiz DVM        Berry, Silva and Torres
# Lori Phillips                  Erin Yang         Beck, Collins and Bush
# Aaron Wilson                James Carter                Flores-Mcdaniel
# James Johnson             Shannon Harvey                   Fisher Group
# Dan Nash                 Matthew Kennedy        Cain, Gordon and Campos
# Jennifer Sutton          Mackenzie Mason                    Lopez-Horne
# Jennifer Gibson             Jonathan Gay                  Thomas-Morris
# Patrick Smith               Sheri Barker      Aguilar, Beltran and King
# Kenneth Yu                   Randy Davis                     Kim-Taylor
# Melinda Dunn                 Erin Grimes                      Brown PLC
# Courtney Wilson         Anthony Williams                   Brandt Group
# Theresa Anderson              David Cook                    Stevens Inc
# Nathan Campbell            Nathan Curtis                    Baker-Perez
# Hannah Garcia              Juan Richards         Allen, Hood and Mendez
# Angela Griffith MD          Mary Johnson                    Brown Group
# Aimee Farmer               Rebecca Perez                   Watson-Hayes
# Jill Brandt                Barbara Scott                    Berry-Weber
# John Perez               Brittany Pierce                   Bradshaw Ltd
# Crystal Gardner           Rebecca Mcneil                      May Group
# Dustin Myers              Joshua Jenkins                   Robinson PLC
# Renee Taylor                Sandra Green  Ramirez, Campbell and Schmidt
#
#                     Insurance Provider  Billing Amount Admission Type  \
# Elizabeth Wong              Blue Cross           39130       Elective
# Mark Barnes                      Aetna           17699         Urgent
# Benjamin Stone        UnitedHealthcare           27614      Emergency
# Jacob Atkins                     Cigna           34022         Urgent
# Mercedes Mitchell                Aetna           17648      Emergency
# Jonathan Brady                Medicare           39942         Urgent
# Lisa Ramirez                Blue Cross           40948       Elective
# Mark Maxwell                Blue Cross           19703      Emergency
# Abigail Horn                     Cigna            8107      Emergency
# Kayla Herrera                    Aetna           26790         Urgent
# Elizabeth Martinez            Medicare           31753       Elective
# Samuel Johnson              Blue Cross           13393      Emergency
# Robert Payne                Blue Cross           41399         Urgent
# Sandra Green                Blue Cross           21078       Elective
# Daniel Wilkinson              Medicare            3975      Emergency
# Richard Morrow        UnitedHealthcare           34927      Emergency
# Jonathan Cunningham   UnitedHealthcare            7759         Urgent
# John Marshall         UnitedHealthcare           39922      Emergency
# Nancy Lopez                 Blue Cross           14300      Emergency
# Joyce Vaughn                     Aetna           16932      Emergency
# Carrie Lowe                 Blue Cross           35047      Emergency
# Trevor Compton                   Aetna           47044       Elective
# Kimberly Cruz                    Aetna           11618         Urgent
# Adam Bryant           UnitedHealthcare           13919      Emergency
# Lori Phillips                    Aetna           43238       Elective
# Aaron Wilson                     Cigna            6627      Emergency
# James Johnson                    Cigna           11753      Emergency
# Dan Nash                    Blue Cross           12930       Elective
# Jennifer Sutton                  Aetna            8841       Elective
# Jennifer Gibson       UnitedHealthcare           40389      Emergency
# Patrick Smith                    Cigna           45004         Urgent
# Kenneth Yu                       Cigna           13939         Urgent
# Melinda Dunn                Blue Cross           39887      Emergency
# Courtney Wilson                  Aetna           38490      Emergency
# Theresa Anderson                 Aetna           19906      Emergency
# Nathan Campbell       UnitedHealthcare           48049         Urgent
# Hannah Garcia                    Aetna           46396         Urgent
# Angela Griffith MD    UnitedHealthcare           46231         Urgent
# Aimee Farmer                  Medicare            2800         Urgent
# Jill Brandt                      Aetna           28446      Emergency
# John Perez                       Cigna           44421         Urgent
# Crystal Gardner             Blue Cross           35122         Urgent
# Dustin Myers                     Cigna            1828      Emergency
# Renee Taylor                     Aetna           42271       Elective
#
#                     Discharge Date   Medication  Test Results
# Elizabeth Wong          2021-08-01      Aspirin  Inconclusive
# Mark Barnes             2021-11-22   Penicillin  Inconclusive
# Benjamin Stone          2018-12-04      Lipitor  Inconclusive
# Jacob Atkins            2020-11-23      Aspirin  Inconclusive
# Mercedes Mitchell       2019-01-07      Aspirin        Normal
# Jonathan Brady          2023-06-27      Aspirin        Normal
# Lisa Ramirez            2019-12-30  Paracetamol      Abnormal
# Mark Maxwell            2022-06-01  Paracetamol  Inconclusive
# Abigail Horn            2021-11-13  Paracetamol        Normal
# Kayla Herrera           2022-07-12   Penicillin        Normal
# Elizabeth Martinez      2022-02-02      Lipitor  Inconclusive
# Samuel Johnson          2023-02-04  Paracetamol        Normal
# Robert Payne            2021-01-08    Ibuprofen  Inconclusive
# Sandra Green            2021-11-08      Aspirin      Abnormal
# Daniel Wilkinson        2021-11-03      Aspirin        Normal
# Richard Morrow          2019-08-26      Lipitor        Normal
# Jonathan Cunningham     2020-11-27   Penicillin  Inconclusive
# John Marshall           2021-12-05      Lipitor  Inconclusive
# Nancy Lopez             2023-09-01    Ibuprofen  Inconclusive
# Joyce Vaughn            2021-10-22      Lipitor        Normal
# Carrie Lowe             2022-06-05  Paracetamol      Abnormal
# Trevor Compton          2019-12-05      Aspirin        Normal
# Kimberly Cruz           2023-02-04      Aspirin        Normal
# Adam Bryant             2021-04-26    Ibuprofen      Abnormal
# Lori Phillips           2022-02-05    Ibuprofen        Normal
# Aaron Wilson            2020-08-09  Paracetamol        Normal
# James Johnson           2022-11-04   Penicillin        Normal
# Dan Nash                2021-09-29    Ibuprofen  Inconclusive
# Jennifer Sutton         2022-06-21      Aspirin      Abnormal
# Jennifer Gibson         2019-02-03  Paracetamol  Inconclusive
# Patrick Smith           2019-12-01  Paracetamol      Abnormal
# Kenneth Yu              2023-09-20      Aspirin  Inconclusive
# Melinda Dunn            2021-03-09    Ibuprofen  Inconclusive
# Courtney Wilson         2022-03-12   Penicillin        Normal
# Theresa Anderson        2022-02-14    Ibuprofen  Inconclusive
# Nathan Campbell         2019-01-07      Lipitor      Abnormal
# Hannah Garcia           2023-01-14      Lipitor  Inconclusive
# Angela Griffith MD      2021-01-16      Lipitor      Abnormal
# Aimee Farmer            2019-08-25    Ibuprofen      Abnormal
# Jill Brandt             2020-07-22      Lipitor      Abnormal
# John Perez              2020-11-21  Paracetamol      Abnormal
# Crystal Gardner         2021-03-06      Aspirin        Normal
# Dustin Myers            2022-10-17    Ibuprofen        Normal
# Renee Taylor            2020-06-10      Lipitor  Inconclusive

# %% [markdown]
# Before we proceed: Review the changes we have made to our dataframe.

# %%
# Display the dataframe shape
#...
# Display the columns
#...
# Display the first 6 raws
#...

# %% [markdown]
# Great work 🦾, Now we know our dataset, so let's plot 📈📊

# %% [markdown]
# ---
# # Data Visualization using Matplotlib

# %% [markdown]
# ![téléchargé (1).png](data:image/png;base64,...)

# %% [markdown]
# ### Matplotlib: Standard Python Visualization Library 📊
#
# The primary plotting library used is [Matplotlib](http://matplotlib.org/).  As mentioned on their website:
# >Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms.
#
# If you are aspiring to create impactful visualization with python, Matplotlib is an essential tool to have at your disposal. 🤩

# %%
# For this part we will only use a selection of the dataset
# Select a random sample of 1000 rows
df= df.sample(n=1000, random_state=42)

# %% [markdown]
# ### Matplotlib.Pyplot
#
# One of the core aspects of Matplotlib is `matplotlib.pyplot`. It is Matplotlib's scripting layer. Each `pyplot` function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %% [markdown]
# Let's start by importing `Matplotlib` and `Matplotlib.pyplot` as follows:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# *optional: check if Matplotlib is loaded.

# %%
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.10.0

# %% [markdown]
# *optional: apply a style to Matplotlib.

# %%
print(plt.style.available)
mpl.style.use(['ggplot']) # optional: for ggplot-like style
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Line Pots 📈

# %% [markdown]
# **What is a line plot and why use it?**
#
# A line chart or line plot is a type of plot which displays information as a series of data points called 'markers' connected by straight line segments. It is a basic type of chart common in many fields.*
#
# Use line plot when you have a continuous data set.
# These are best suited for trend-based visualizations of data over a period of time.

# %%
# Example: Line Plot
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a line plot
plt.plot(x, y)

# Add title and labels
plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Display the plot
plt.show()

# %% [markdown]
# **Let's try with healthcare usecase:**
#
# **Question:** Using the dataset, create a line plot to show the number of patient admissions in 2022."using `df.plot()`.

# %% [markdown]
# Let's break it down together :
# First let's filter for the correct date range :

# %%
# Filter for 2022 admissions
df_2022 = df[(df['Entry Date'].dt.year == 2022) ]

# %% [markdown]
# Then let's group the data by day to count admissions

# %%
# Count number of admissions per day
admission_counts_2022 = df_2022.groupby('Entry Date').size()

# Compute cumulative sum
cumulative_admissions = admission_counts_2022.cumsum() # each patient added is accounted for in the next day

# %% [markdown]
# * plt.figure(figsize=(10, 5)): This creates a new figure with a **size** of 10 inches wide and 5 inches tall.

# %%
# Plot the cumulative line chart
plt.figure(figsize=(10, 5))
plt.plot(cumulative_admissions.index, cumulative_admissions.values, linestyle='-', color='b') #plot the cumulative values

# Add labels and title
plt.xlabel("Date")
plt.ylabel("Number of Admissions")
plt.title("Number of Admissions in 2022")
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# Customizing Labels and Title :
# Having a plot as such does not give any information about what it represents, so we need to label it, here is how 👇

# %%
plt.plot(cumulative_admissions.index, cumulative_admissions.values, marker='+', linestyle='-', color='b') # We can also change the marker
# Let's customize labels and title
plt.xlabel('Entry Date') # This adds a label to the x-axis
plt.ylabel('Number of Admissions') # This adds a label to the y-axis
plt.title('Number of Admissions in November 2022') # This puts a Title to our plot
# Out:
# Text(0.5, 1.0, 'Number of Admissions in November 2022')

# %% [markdown]
# ###Try it yourself 🤩

# %% [markdown]
# Step 1: Get the dataset for 2020, and display dataframe.

# %%
### type your answer here

# %% [markdown]
# Step 2: Plot a readable graph. With X and Y labels and a title. 💪

# %%
### type your answer here

# %% [markdown]
# --> Try passing 'kind' to plot

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- Here is how :
# df.plot(kind='line')
# -->

# %% [markdown]
# Line plot is a handy tool to display several dependent variables against one independent variable. However, it is recommended that no more than 5-10 lines on a single graph; any more than that and it becomes difficult to interpret.

# %% [markdown]
# ***Want to try something harder 💪 try to create a number of patients per day (considering number of admissions AND Discharge Date 😉)***

# %% [markdown]
# Congratulations! you have learned how to wrangle data with python and create a line plot with Matplotlib.

# %% [markdown]
# # Area Plots 📈

# %% [markdown]
# An **Area Plot** (or stacked area plot) is used to visualize cumulative data over time. It is similar to a line plot, but the area below the line is filled with color, making it easier to see the contribution of each component to the whole.

# %% [markdown]
# For example; let's see the number of admissions by type, for each month :

# %%
# Convert 'Entry Date' to datetime
df['Entry Date'] = pd.to_datetime(df['Entry Date'])

# Extract Month from 'Entry Date' to group by
df['Month'] = df['Entry Date'].dt.to_period('M')  # You can also use 'Y' for Year

# Group by 'Month' and 'Admission Type' to get the counts
admission_counts = df.groupby(['Month', 'Admission Type']).size().unstack(fill_value=0)

# Create an Area Plot
admission_counts.plot(kind='area', stacked=False)

# Add title, labels, and legend
plt.title("Admission Type Distribution Over Time")
plt.xlabel("Time (Month)")
plt.ylabel("Number of Admissions")
plt.legend(title="Admission Type", loc="upper left")

# Display the plot
plt.show()

# %% [markdown]
# As you see, it doesn't look good --> That's the effect of *stacked*

# %%
# Extract Month from 'Entry Date' to group by
df['Month'] = df['Entry Date'].dt.to_period('M')  # You can also use 'Y' for Year

# Group by 'Month' and 'Admission Type' to get the counts
admission_counts = df.groupby(['Month', 'Admission Type']).size().unstack(fill_value=0)

# Create an Area Plot
admission_counts.plot(kind='area', stacked=True) # By changing Stacked to "True"

# Add title, labels, and legend
plt.title("Admission Type Distribution Over Time")
plt.xlabel("Time (Month)")
plt.ylabel("Number of Admissions")
plt.legend(title="Admission Type", loc="upper left")

# Display the plot
plt.show()

# %% [markdown]
# We can make th stacked plots transparent by changing *alpha* value

# %%
# Extract Month from 'Entry Date' to group by
df['Month'] = df['Entry Date'].dt.to_period('M')  # You can also use 'Y' for Year

# Group by 'Month' and 'Admission Type' to get the counts
admission_counts = df.groupby(['Month', 'Admission Type']).size().unstack(fill_value=0)

# Create an Area Plot
admission_counts.plot(kind='area', stacked=True, alpha=0.5) # Play with alpha value to see the difference

# Add title, labels, and legend
plt.title("Admission Type Distribution Over Time")
plt.xlabel("Time (Month)")
plt.ylabel("Number of Admissions")
plt.legend(title="Admission Type", loc="upper left")

# Display the plot
plt.show()

# %% [markdown]
# Here Do the same for each YEAR now 👇

# %% [markdown]
# Double click here 🈁 for the solution
# <!-- # Extract Year from 'Entry Date' to group by
# df['Year'] = df['Entry Date'].dt.to_period('Y')  # 'Y' for Year
#
# # Group by 'Year' and 'Admission Type' to get the counts
# admission_counts = df.groupby(['Year', 'Admission Type']).size().unstack(fill_value=0)
#
# # Create an Area Plot
# admission_counts.plot(kind='area', stacked=True, alpha=0.6)
#
# # Add title, labels, and legend
# plt.title("Admission Type Distribution Over Time")
# plt.xlabel("Time (Year)")
# plt.ylabel("Number of Admissions")
# plt.legend(title="Admission Type", loc="upper left")
#
# # Display the plot
# plt.show() -->

# %% [markdown]
# #Bar Plots 📊

# %% [markdown]
# A bar plot is a way of representing data where the *length* of the bars represents the magnitude/size of the feature/variable. Bar graphs usually represent numerical and categorical variables grouped in intervals.

# %% [markdown]
# **Use case:** Let's see the disease distribution in our patients :

# %%
# Count the number of patients for each disease
disease_counts = df['Disease'].value_counts()

# Create a bar plot (using a bar chart here as it is better suited for categorical data)
disease_counts.plot(kind='bar', edgecolor='black')

# Add title and labels
plt.title("Disease Distribution Among Patients")
plt.xlabel("Disease")
plt.ylabel("Number of Patients")

# Display the plot
plt.show()

# %% [markdown]
# Let's try the distribution by patient gender : answering the question : ***which gender has more disease?***

# %%
# Now we Group the data by Gender and Disease, and count occurrences
gender_disease_counts = df.groupby(['Gender', 'Disease']).size().unstack()

# Plot the bar plot for disease distribution by gender
gender_disease_counts.plot(kind='bar', stacked=True, edgecolor='black')

# Add title and labels
plt.title("Disease Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Patients")

# Display the plot
plt.show()

# %% [markdown]
# Stacked this way in not much readable nor representable, so let's try to group by disease first :

# %%
# Now we Group the data by Gender and Disease, and count occurrences
gender_disease_counts = df.groupby(['Disease', 'Gender']).size().unstack()

# Disease by Gender
gender_disease_counts.plot(kind='bar', edgecolor='black')

plt.title("Disease Distribution by Gender")
plt.xlabel("Disease")
plt.ylabel("Number of Patients")
plt.show()

# %% [markdown]
# Better ✔ we can also change the colors used for the bars, here :

# %%
# Plotting
gender_disease_counts.plot(kind='bar', color=["#891652", "#EABE6C"])
plt.title('Count of Diseases by Gender')
plt.xlabel('Disease')
plt.ylabel('Number of Patients')
plt.xticks(rotation=0) #eliminate the name rotation
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# - What we have been plotting is what's called Vertical bar plots, which are the default type of bar plots
#
# Vertical bar plots are particuarly useful in analyzing time series data. One disadvantage is that they lack space for text labelling at the foot of each bar.

# %% [markdown]
# ###Horizontal Bar Plot 📊
#
# Sometimes it is more practical to represent the data horizontally, especially if you need more room for labelling the bars. In horizontal bar plots, the y-axis is used for labelling, and the length of bars on the x-axis corresponds to the magnitude of the variable being measured. As you will see, there is more room on the y-axis to  label categetorical variables.
#
#
# For that we pass **barh** to kind 👇

# %%
df.groupby('Disease')['Billing Amount'].mean().sort_values().plot(kind='barh', color='coral') # barh for horizontal
plt.title('Average Billing Amount per Disease')
plt.xlabel('Billing Amount')
plt.ylabel('Disease')
plt.show()

# %% [markdown]
# - Have you noticed something strange about "Obesity" ? Go back you'll see it in the graphs 👆

# %% [markdown]
# # Histograms 📉
#
# A histogram is a way of representing the *frequency* distribution of numeric dataset.
# ##The way it works ⁉
# it partitions the *x-axis* into ***bins***, assigns each data point in our dataset to a bin, and then counts the number of data points that have been assigned to each bin. So the *y-axis* is the frequency or the number of data points in each bin.

# %%
# Plotting Age distribution
plt.hist(df['Age'], bins=10, edgecolor='black', color='skyblue')

plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * *Note* that we can change the bin size and usually one needs to tweak it so that the distribution is displayed nicely.

# %% [markdown]
# Try it yourself here with a bin size=5 👇

# %%
#Your Answer

# %% [markdown]
# We can also graph this distribution by passing `kind=hist` to `plot()`.

# %%
df['Age'].plot(kind='hist', figsize=(8, 5), bins=10, edgecolor='black')

plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Tip:
# For a full listing of colors available in Matplotlib, run the following code in your python shell:
# ```python
# import matplotlib
# for name, hex in matplotlib.colors.cnames.items():
#     print(name, hex)
# ```

# %% [markdown]
# # Pie Charts 🥧
#
# A `pie chart` is a circular graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media.
# We can create pie charts in Matplotlib using `plt.pie()` OR by passing in the `kind=pie` keyword.

# %%
df['Gender'].value_counts().plot(
    kind='pie',  #Type of the plot
    autopct='%1.1f%%', # Displays percentage values on the pie slices.
    startangle=90, # Rotates the starting position of the first slice to 90 degrees --> Try 0 to see the difference
    figsize=(5, 6), # Figure size
    explode = (0.05, 0) , # Explode the 1st slice
    shadow=True, # Makes a shadow
    colors=['#ff9999', '#66b3ff'] # The colors to use
)
plt.title("Patient Gender Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# # Scatter Plots <a id="10"></a>
#
# A `scatter plot` (2D) is a useful method of comparing variables against each other. `Scatter` plots look similar to `line plots` in that they both map independent and dependent variables on a 2D graph.
#
# While the datapoints are connected together by a line in a line plot, they are not connected in a scatter plot. The data in a scatter plot is considered to express a trend.
#
# - With further analysis using tools like regression, we can mathematically calculate this relationship and use it to predict trends outside the dataset.

# %%
plt.scatter(df['Age'], df['Billing Amount'], alpha=0.6, color='purple')
plt.title('Age vs Billing Amount')
plt.xlabel('Age')
plt.ylabel('Billing Amount')
plt.show()

# %% [markdown]
# #Box Plot

# %% [markdown]
# A box plot (also known as a *box-and-whisker* plot) is a statistical graphic used to visualize the distribution of a dataset. It shows the central ***tendency***, ***variability***, and ***outliers*** of the data. A box plot is particularly useful for comparing distributions across different groups or categories.

# %%
df['Stay Duration'] = (df['Discharge Date'] - df['Entry Date']).dt.days

# Group by Medication and calculate the distribution of Stay Duration
plt.figure(figsize=(12, 6))

df.boxplot(column='Stay Duration', by='Medication')

# Titles and labels
plt.title('Stay Duration by Medication')
plt.suptitle('')  # Remove the default title generated by boxplot
plt.xlabel('Stay Duration (days)')
plt.ylabel('Medication')

# Display the plot
plt.show()

# %% [markdown]
# Let's do some format changing to make it look better :

# %%
df['Stay Duration'] = (df['Discharge Date'] - df['Entry Date']).dt.days

# Group by Medication and calculate the distribution of Stay Duration
plt.figure(figsize=(12, 6))
df.boxplot(column='Stay Duration', by='Medication',
           vert=False,  # Turn into vertical orientation
           patch_artist=True, # Fills the boxes with color.
           medianprops=dict(color="red", linewidth=2), # Customize the appearance of the median line inside the box.
           boxprops=dict(facecolor='lightblue', color='blue'), # Controls the appearance of the boxes in the box plot.
           whiskerprops=dict(color="blue", linewidth=1.5)) # Customize the appearance of the whiskers (the lines extending from the box).

# Titles and labels
plt.title('Stay Duration by Medication')
plt.suptitle('')  # Remove the default title generated by boxplot
plt.xlabel('Stay Duration (days)')
plt.ylabel('Medication')

# Display the plot
plt.show()

# %% [markdown]
# #SubPlots 📉 📊

# %% [markdown]
# For further analysis, you can make different subplots in one plot, here is a simple example :

# %%
## Creating Subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'yo')
